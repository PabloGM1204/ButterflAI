# %% [markdown]
# # Conversión de los modelos a Tflite.
#
# Este cuaderno tiene la finalidad de convertir el modelo de detección y de clasifiación a TFlite, de manera que se pueda utilizar en una aplicación móvil desarrollada con Flutter.
#
# El **detector** tiene la extensión `.pt`, por lo que primero se debe convertir a `.onnx` para poder cambiarse después a `.tf` y, por último, conseguir el `.tflite`.
#
# El **clasificador** tiene la extensión `.keras`, por lo que se puede pasar directamente.

# %% [markdown]
# ## Instalaciones/Imports

# %%
# !pip install onnx2tf
# !pip install onnx
# !pip install onnx-graphsurgeon
# !pip install sng4onnx
# !pip install ultralytics
# !pip install onnxslim
# Out:
# Collecting onnx2tf
#   Downloading onnx2tf-1.26.8-py3-none-any.whl.metadata (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 kB 4.5 MB/s eta 0:00:00
# Downloading onnx2tf-1.26.8-py3-none-any.whl (446 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 15.9 MB/s eta 0:00:00
# Installing collected packages: onnx2tf
# Successfully installed onnx2tf-1.26.8
# Collecting onnx
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx) (4.25.6)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 82.4 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.17.0
# Collecting onnx-graphsurgeon
#   Downloading onnx_graphsurgeon-0.5.5-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from onnx-graphsurgeon) (1.26.4)
# Requirement already satisfied: onnx>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from onnx-graphsurgeon) (1.17.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx>=1.14.0->onnx-graphsurgeon) (4.25.6)
# Downloading onnx_graphsurgeon-0.5.5-py2.py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: onnx-graphsurgeon
# Successfully installed onnx-graphsurgeon-0.5.5
# Collecting sng4onnx
#   Downloading sng4onnx-1.0.4-py3-none-any.whl.metadata (4.6 kB)
# Downloading sng4onnx-1.0.4-py3-none-any.whl (5.9 kB)
# Installing collected packages: sng4onnx
# Successfully installed sng4onnx-1.0.4
# Collecting ultralytics
#   Downloading ultralytics-8.3.80-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.80-py3-none-any.whl (921 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.9/921.9 kB 21.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.80 ultralytics-thop-2.0.14
# Collecting onnxslim
#   Downloading onnxslim-0.1.48-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: onnx in /usr/local/lib/python3.11/dist-packages (from onnxslim) (1.17.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxslim) (1.13.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxslim) (24.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from onnx->onnxslim) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx->onnxslim) (4.25.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxslim) (1.3.0)
# Downloading onnxslim-0.1.48-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: onnxslim
# Successfully installed onnxslim-0.1.48

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# ## .pt a .onnx
#
# Para realizar este paso, es necesario contar con el modelo `.pt`, en nuestro caso, *best.pt*.

# %%
# !yolo export model=best.pt format=onnx opset=12
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 12...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success ✅ 2.1s, saved as 'best.onnx' (11.7 MB)
#
# Export complete (2.9s)
# Results saved to /content
# Predict:         yolo predict task=detect model=best.onnx imgsz=640
# Validate:        yolo val task=detect model=best.onnx imgsz=640 data=modificado_copy/data.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# ## .onnx a .tf
#
# Una vez conseguido el `.onnx` hay que pasarlo a `.tf`.
#
# A diferencia del anterior, que nos daba el *best.onnx* directamente descargado, en este paso se descargará una carpeta con el nombre que hayamos puesto (*detector_tf*).

# %%
# !onnx2tf -i best.onnx -o detector_tf
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740587746.391628    4329 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740587746.406094    4329 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/onnx2tf/onnx2tf.py", line 652, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'onnxsim'
#
# WARNING: Failed to optimize the onnx file.
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: images shape: [1, 3, 640, 640] dtype: float32
#
# INFO: 2 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.0/conv/Conv
# INFO:  input_name.1: images shape: [1, 3, 640, 640] dtype: float32
# INFO:  input_name.2: model.0.conv.weight shape: [16, 3, 3, 3] dtype: float32
# INFO:  input_name.3: model.0.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad/Pad:0 shape: (1, 642, 642, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 3 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.0/act/Sigmoid
# INFO:  input_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  output_name.1: wa/model.0/act/Sigmoid_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid/Sigmoid:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 4 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.0/act/Mul
# INFO:  input_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  input_name.2: wa/model.0/act/Sigmoid_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  output_name.1: wa/model.0/act/Mul_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid/Sigmoid:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_3/Mul:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 5 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.1/conv/Conv
# INFO:  input_name.1: wa/model.0/act/Mul_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  input_name.2: model.1.conv.weight shape: [32, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_1/Pad:0 shape: (1, 322, 322, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 6 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.1/act/Sigmoid
# INFO:  input_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_1/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_1/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 7 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.1/act/Mul
# INFO:  input_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_1/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_1/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_7/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 8 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/cv1/conv/Conv
# INFO:  input_name.1: wa/model.1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.cv1.conv.weight shape: [32, 32, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_7/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 9 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_2/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 10 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/cv1/act/Mul
# INFO:  input_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_2/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_11/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 11 / 235
# INFO: onnx_op_type: Split onnx_op_name: wa/model.2/Split
# INFO:  input_name.1: wa/model.2/cv1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/Split_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.2: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_11/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: val: [16, 16]
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split/split:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 12 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv1.conv.weight shape: [16, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv1.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 13 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_3/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 14 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_3/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_15/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 15 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.2/m.0/cv1/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv2.conv.weight shape: [16, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv2.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_15/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_4/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 16 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_4/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_4/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 17 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_4/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_4/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_19/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 18 / 235
# INFO: onnx_op_type: Add onnx_op_name: wa/model.2/m.0/Add
# INFO:  input_name.1: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/Add_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_19/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_6/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 19 / 235
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.2/Concat
# INFO:  input_name.1: wa/model.2/Split_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.3: wa/model.2/m.0/Add_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/Concat_output_0 shape: [1, 48, 160, 160] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.split/split:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_6/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.axis: val: 3
# INFO:  output.1.output: name: tf.concat/concat:0 shape: (1, 160, 160, 48) dtype: <dtype: 'float32'>
#
# INFO: 20 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/cv2/conv/Conv
# INFO:  input_name.1: wa/model.2/Concat_output_0 shape: [1, 48, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.cv2.conv.weight shape: [32, 48, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat/concat:0 shape: (1, 160, 160, 48) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 48, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 21 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_5/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 22 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/cv2/act/Mul
# INFO:  input_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/cv2/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_5/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_25/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 23 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.3/conv/Conv
# INFO:  input_name.1: wa/model.2/cv2/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: model.3.conv.weight shape: [64, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.3.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_2/Pad:0 shape: (1, 162, 162, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_8/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 24 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.3/act/Sigmoid
# INFO:  input_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.3/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_8/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_6/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 25 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.3/act/Mul
# INFO:  input_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.3/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.3/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_8/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_6/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_29/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 26 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/cv1/conv/Conv
# INFO:  input_name.1: wa/model.3/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.cv1.conv.weight shape: [64, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_29/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_9/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 27 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_9/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_7/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 28 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_9/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_7/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_33/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 29 / 235
# INFO: onnx_op_type: Split onnx_op_name: wa/model.4/Split
# INFO:  input_name.1: wa/model.4/cv1/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/Split_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.2: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_33/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: val: [32, 32]
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split_1/split:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 30 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_10/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 31 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_10/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_8/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 32 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_10/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_8/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_37/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 33 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/m.0/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_37/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_11/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 34 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_11/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_9/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 35 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_11/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_9/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_41/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 36 / 235
# INFO: onnx_op_type: Add onnx_op_name: wa/model.4/m.0/Add
# INFO:  input_name.1: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_41/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_13/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 37 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.1/cv1/conv/Conv
# INFO:  input_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.1.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.1.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_13/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 38 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.1/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_10/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 39 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.1/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_10/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_47/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 40 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.1/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/m.1/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.1.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.1.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_47/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_15/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 41 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.1/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_15/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_11/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 42 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.1/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_15/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_11/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_51/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 43 / 235
# INFO: onnx_op_type: Add onnx_op_name: wa/model.4/m.1/Add
# INFO:  input_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_13/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_51/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_17/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 44 / 235
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.4/Concat
# INFO:  input_name.1: wa/model.4/Split_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.3: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.4: wa/model.4/m.1/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/Concat_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.split_1/split:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_13/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.4.input3: name: tf.math.add_17/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.5.axis: val: 3
# INFO:  output.1.output: name: tf.concat_1/concat:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 45 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/Concat_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.cv2.conv.weight shape: [64, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_1/concat:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_18/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 46 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_18/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_12/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 47 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/cv2/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_18/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_12/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_57/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 48 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.5/conv/Conv
# INFO:  input_name.1: wa/model.4/cv2/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: model.5.conv.weight shape: [128, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.5.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_3/Pad:0 shape: (1, 82, 82, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_19/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 49 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.5/act/Sigmoid
# INFO:  input_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.5/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_19/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_13/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 50 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.5/act/Mul
# INFO:  input_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.5/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.5/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_19/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_13/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_61/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 51 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/cv1/conv/Conv
# INFO:  input_name.1: wa/model.5/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.cv1.conv.weight shape: [128, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.cv1.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_61/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_20/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 52 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_20/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 53 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_20/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_65/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 54 / 235
# INFO: onnx_op_type: Split onnx_op_name: wa/model.6/Split
# INFO:  input_name.1: wa/model.6/cv1/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/Split_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.2: wa/model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_65/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: val: [64, 64]
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split_2/split:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split_2/split:1 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 55 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv1.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split_2/split:1 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_21/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 56 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_21/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 57 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_21/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_69/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 58 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.6/m.0/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv2.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_69/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_22/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 59 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_22/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_16/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 60 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_22/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_16/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_73/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 61 / 235
# INFO: onnx_op_type: Add onnx_op_name: wa/model.6/m.0/Add
# INFO:  input_name.1: wa/model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv2/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/Add_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split_2/split:1 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_73/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_24/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 62 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.1/cv1/conv/Conv
# INFO:  input_name.1: wa/model.6/m.0/Add_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.1.cv1.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.1.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_24/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_25/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 63 / 235
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.1/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.1/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_25/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_17/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 64 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.1/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/m.1/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/m.1/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_25/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_17/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_79/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 65 / 235
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.1/cv2/conv/Conv
# INFO:  input_name.1: wa/model.6/m.1/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.1.cv2.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.1.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.1/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_79/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# ...
# INFO:  output.1.output: name: tf.math.add_75/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 230 / 235
# INFO: onnx_op_type: Add onnx_op_name: wa/model.22/Add_2
# INFO:  input_name.1: wa/model.22/Sub_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Add_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Add_2_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.subtract/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_75/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_76/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 231 / 235
# INFO: onnx_op_type: Sub onnx_op_name: wa/model.22/Sub_1
# INFO:  input_name.1: wa/model.22/Add_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Sub_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Sub_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.math.add_75/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.subtract/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_1/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 232 / 235
# INFO: onnx_op_type: Div onnx_op_name: wa/model.22/Div_1
# INFO:  input_name.1: wa/model.22/Add_2_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_11_output_0 shape: [] dtype: float32
# INFO:  output_name.1: wa/model.22/Div_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.math.add_76/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.divide/truediv:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 233 / 235
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_4
# INFO:  input_name.1: wa/model.22/Div_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Sub_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Concat_4_output_0 shape: [1, 4, 8400] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.divide/truediv:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.math.subtract_1/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 1
# INFO:  output.1.output: name: tf.concat_20/concat:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
#
# INFO: 234 / 235
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.22/Mul_2
# INFO:  input_name.1: wa/model.22/Concat_4_output_0 shape: [1, 4, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_12_output_0 shape: [1, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Mul_2_output_0 shape: [1, 4, 8400] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.concat_20/concat:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 8400) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_252/Mul:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
#
# INFO: 235 / 235
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_5
# INFO:  input_name.1: wa/model.22/Mul_2_output_0 shape: [1, 4, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Sigmoid_output_0 shape: [1, 1, 8400] dtype: float32
# INFO:  output_name.1: output0 shape: [1, 5, 8400] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.multiply_252/Mul:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.math.sigmoid_57/Sigmoid:0 shape: (1, 1, 8400) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 1
# INFO:  output.1.output: name: tf.concat_21/concat:0 shape: (1, 5, 8400) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# Saved artifact at 'detector_tf'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 5, 8400), dtype=tf.float32, name=None)
# Captures:
#   134411727283664: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134411727282512: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   134411727284432: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   134411727285392: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134411727287120: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   134411727286736: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411727287696: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   134411727288080: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411727288464: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   134411727288656: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   134411727287888: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   134411727288848: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   134411727288272: TensorSpec(shape=(1, 1, 48, 32), dtype=tf.float32, name=None)
#   134411727289424: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411727289616: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134411727289040: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   134411727289232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411727289808: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134411727290000: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411727290192: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   134411678253520: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411678253328: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   134411678253712: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411678254096: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   134411678254288: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411678253136: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   134411678254480: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411678255056: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   134411678254864: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678255248: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134411678253904: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   134411678254672: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678255440: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   134411678255824: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678256016: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678256400: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678256208: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678256592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678256976: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678257168: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678255632: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678257360: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678257936: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   134411678257744: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678258128: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134411678256784: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   134411678257552: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134411678258320: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   134411678258704: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134411678258896: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134411678259280: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678259088: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134411678259472: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678260048: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   134411678259856: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134411678258512: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   134411678260240: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678260432: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   134411678260624: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134411678260816: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   134411678261968: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678262160: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678263696: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678263120: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678263888: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678264272: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   134411678264080: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678264464: TensorSpec(shape=(1, 1, 192, 64), dtype=tf.float32, name=None)
#   134411678264656: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678264848: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   134411678265232: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411678265040: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   134411678265424: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134411678265808: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   134411678265616: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678266192: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134411678266000: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678262928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678267920: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   134411678268112: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411678269264: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678269072: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674402896: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411674403664: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674404240: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   134411674403472: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411674404048: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134411674403088: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134411674403856: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411674405776: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   134411674405968: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134411674407312: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134411674406928: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411674409232: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134411674408272: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134411674407504: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   134411674408080: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134411674407120: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   134411674408848: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   134411674404816: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   134411674404432: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   134411678266960: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678266576: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411674407696: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674407888: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674404624: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674403280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678266768: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678266384: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674408464: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411674408656: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411674405392: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411674405200: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678267536: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411678267344: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134411674409424: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674409040: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674405584: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674405008: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678267728: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678267152: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674410000: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   134411674410192: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134411674406352: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   134411674406160: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134411678268496: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   134411678268304: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134411674409616: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674409808: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   134411674406736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411674406544: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   134411678268880: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134411678268688: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   134411674411536: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   134411674410576: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134411674412112: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134411674411152: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134411674412688: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134411674413648: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   134411674411920: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
# saved_model output complete!
# I0000 00:00:1740587763.122179    4329 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740587763.122535    4329 single_machine.cc:361] Starting new session
# W0000 00:00:1740587763.974704    4329 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1740587763.974767    4329 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Float32 tflite output complete!
# I0000 00:00:1740587764.989708    4329 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# I0000 00:00:1740587764.989908    4329 single_machine.cc:361] Starting new session
# W0000 00:00:1740587765.740346    4329 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1740587765.740402    4329 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Float16 tflite output complete!

# %% [markdown]
# ## .tf a .tflite
#
# Por último, pasamos el `.tf` a `.tflite` introduciendo el nombre del directorio creado.

# %%
# Carga el modelo TensorFlow
converter = tf.lite.TFLiteConverter.from_saved_model("detector_tf")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]

# Convierte a TFLite
tflite_model = converter.convert()

# Guarda el modelo convertido
with open("detector.tflite", "wb") as f:
    f.write(tflite_model)

print("Conversión completada: detector.tflite")
# Out:
# Conversión completada: detector.tflite

# %% [markdown]
# ## .keras a .tflite
#
# Para convertir el modelo de clasificación de `.keras` a `.tflite` solo necesitamos ejecutar la siguiente celda, que nos descargará el modelo directamente.

# %%
# Carga el modelo .keras
model = load_model("clasificador.keras")

# Configura la conversión para usar operadores compatibles
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,
    tf.lite.OpsSet.SELECT_TF_OPS
]
tflite_model = converter.convert()

# Guarda el modelo convertido
with open("clasificador.tflite", "wb") as f:
    f.write(tflite_model)

print("Conversión completada: clasificador.tflite")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Saved artifact at '/tmp/tmp77jnuktu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_3')
# Output Type:
#   TensorSpec(shape=(None, 100), dtype=tf.float32, name=None)
# Captures:
#   132226848918608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848919376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848919952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848921296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848921104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848917456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848921872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848922640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848923024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848924368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848922256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848920144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848925520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848926288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848926672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848927248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848923216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848924176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848928016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848930128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848930320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848930896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848929360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848929552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848928208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226848930704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724498128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724498704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724497360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724501392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724504080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724503696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724501584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132226724509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Conversión completada: clasificador.tflite

# %%
interpreter = tf.lite.Interpreter(model_path="clasificador.tflite")
interpreter.allocate_tensors()
print("Modelo TFLite cargado correctamente.")
# Out:
# Modelo TFLite cargado correctamente.
